# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)
np.set_printoptions(suppress=True, precision=2)

# %%
df = pd.read_csv('eastauries_updated_for_eda.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 station depth_m        date water_temperature_c  \
# 0           0     GP1       S  1987-09-16                18.4
# 1           1     GP2       S  1987-09-16                22.6
# 2           2     GP2       1  1987-09-16                  23
# 3           5     GP3       S  1987-09-16                  22
# 4           6     GP3       1  1987-09-16                21.9
#
#   oxygen_no_of_drops do_meter_mg_per_l use_salinity_corrected_do  \
# 0                 ND               6.7                        ND
# 1                 ND               4.5                        ND
# 2                 ND               6.6                        ND
# 3                 ND               6.5                        ND
# 4                 ND               7.1                        ND
#
#   secchi_depth_m total_depth_m percent_secchi weather water_condition  \
# 0             ND            ND             ND      ND              ND
# ...

# %%
df.drop(columns={'Unnamed: 0'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7585 entries, 0 to 7584
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   station                    7585 non-null   object
#  1   depth_m                    7585 non-null   object
#  2   date                       7585 non-null   object
#  3   water_temperature_c        7585 non-null   object
#  4   oxygen_no_of_drops         7585 non-null   object
#  5   do_meter_mg_per_l          7585 non-null   object
#  6   use_salinity_corrected_do  7585 non-null   object
#  7   secchi_depth_m             7585 non-null   object
#  8   total_depth_m              7585 non-null   object
#  9   percent_secchi             7585 non-null   object
#  10  weather                    7585 non-null   object
#  11  water_condition            7585 non-null   object
#  12  salinity_ppt               7585 non-null   object
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0      1987-09-16
# 1      1987-09-16
# 2      1987-09-16
# 3      1987-09-16
# 4      1987-09-16
#           ...
# 7580   2024-08-29
# 7581   2024-08-29
# 7582   2024-08-29
# 7583   2024-08-29
# 7584   2024-08-29
# Name: date, Length: 7585, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7585 entries, 0 to 7584
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   station                    7585 non-null   object
#  1   depth_m                    7585 non-null   object
#  2   date                       7585 non-null   datetime64[ns]
#  3   water_temperature_c        7585 non-null   object
#  4   oxygen_no_of_drops         7585 non-null   object
#  5   do_meter_mg_per_l          7585 non-null   object
#  6   use_salinity_corrected_do  7585 non-null   object
#  7   secchi_depth_m             7585 non-null   object
#  8   total_depth_m              7585 non-null   object
#  9   percent_secchi             7585 non-null   object
#  10  weather                    7585 non-null   object
#  11  water_condition            7585 non-null   object
#  12  salinity_ppt               7585 non-null   object
# ...

# %%
df =  df.replace('ND', np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7585 entries, 0 to 7584
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   station                    7585 non-null   object
#  1   depth_m                    7557 non-null   object
#  2   date                       7585 non-null   datetime64[ns]
#  3   water_temperature_c        6319 non-null   object
#  4   oxygen_no_of_drops         3056 non-null   object
#  5   do_meter_mg_per_l          3535 non-null   object
#  6   use_salinity_corrected_do  2730 non-null   object
#  7   secchi_depth_m             4792 non-null   object
#  8   total_depth_m              4739 non-null   object
#  9   percent_secchi             4492 non-null   object
#  10  weather                    1398 non-null   object
#  11  water_condition            626 non-null    object
#  12  salinity_ppt               7302 non-null   object
# ...

# %%
df.sample(10)
# Out:
#      station depth_m       date water_temperature_c oxygen_no_of_drops  \
# 2989     WF4       S 2006-07-30                  25               5.93
# 3002     BP1       S 2006-08-13                  24                 11
# 5697     VS1       2 2016-08-07                  24                 15
# 2582     BP4       S 2005-08-07                 NaN                NaN
# 6955     BP3       1 2022-07-17                  25                 15
# 2238     BP5       B 2003-08-24                 NaN                NaN
# 6933     OP3       S 2021-08-01                24.3                NaN
# 2203     BP6       B 2003-08-10                 NaN                NaN
# 6810     GP3       B 2021-08-15                26.7                NaN
# 5326    GTP5       S 2015-07-19                  68                 10
#
#      do_meter_mg_per_l use_salinity_corrected_do secchi_depth_m total_depth_m  \
# 2989               NaN                       NaN            NaN           NaN
# ...

# %%
df.drop(columns={'year'}, inplace=True)

# %% [markdown]
# # COLUMN TYPE CLASSIFICATION
#
# ##NUMERICAL COLUMNS (to be converted to float)
#
# ### Physical Parameters
# - `water_temperature_c` - Water temperature in Celsius
# - `salinity_ppt` - Salinity in parts per thousand
# - `secchi_depth_m` - Secchi disk depth in meters
# - `total_depth_m` - Total water depth in meters
# - `sampling_depth_m` - Sampling depth in meters
# - `conductivity_ms_per_cm` - Conductivity in mS/cm
#
# ### Dissolved Oxygen Parameters
# - `oxygen_no_of_drops` - Oxygen measurement (drop method)
# - `do_meter_mg_per_l` - Dissolved oxygen from meter (mg/L)
# - `use_salinity_corrected_do` - Salinity-corrected dissolved oxygen
#
# ### Nutrient Parameters
# - `po4_um` - Phosphate (μM)
# - `nh4_um` - Ammonium (μM)
# - `nox_um` - Nitrate + Nitrite (μM)
# - `din_um` - Dissolved Inorganic Nitrogen (μM)
# - `don_um` - Dissolved Organic Nitrogen (μM)
# - `tn_um` - Total Nitrogen (μM)
# - `tdn` - Total Dissolved Nitrogen (μM)
#
# ### Particulate Parameters
# - `poc_um` - Particulate Organic Carbon (μM)
# - `pon_um` - Particulate Organic Nitrogen (μM)
# - `ton_um` - Total Organic Nitrogen (μM)
#
# ### Biological Parameters
# - `chla_ug_per_l` - Chlorophyll-a (μg/L)
# - `phaeo_ug_per_l` - Phaeopigments (μg/L)
# - `total_pigments_ug_per_l` - Total Pigments (μg/L)
#
# ### Calculated Ratios/Percentages
# - `c_n_ratio` - Carbon:Nitrogen Ratio
# - `percent_secchi` - Secchi depth as % of total depth
# - `ratio_chla_chla_phaeo` - Chlorophyll ratio
#
# ---
#
# ## CATEGORICAL COLUMNS (keep as text/category)
# - `station` - Sampling station ID
# - `weather` - Weather conditions during sampling
# - `water_condition` - Water condition description
#
# ---

# %% [markdown]
# ### Univariate Analysis
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values

# %% [markdown]
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# #### **Dispersion** is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a data set are spread out from the central tendency (mean, median, or mode) of the data.
#
# There are several measures of dispersion, including:
#
# - **Range**: The difference between the largest and smallest values in a data set.
#
# - **Variance**: The average of the squared deviations of each value from the mean of the data set.
#
# - **Standard Deviation**: The square root of the variance. It provides a measure of the spread of the data that is in the same units as the original data.
#
# - **Interquartile range (IQR)**: The range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data.
#
# Dispersion helps to describe the spread of the data, which can help to identify the presence of outliers and skewness in the data.

# %% [markdown]
# ### Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# # `water_temperature_c`
# ### Conclusions:
# - Average Temperature around 2015 was the highest. above 60 C
# - Average Temperature around 1989 was the lowest. below 7 C

# %%
df['water_temperature_c'].describe()
# Out:
# count     6319
# unique     299
# top         24
# freq       414
# Name: water_temperature_c, dtype: object

# %%
df['water_temperature_c'].unique()
# Out:
# array(['18.4', '22.6', '23', '22', '21.9', '22.1', '21.5', '21.3', '24.9',
#        '25.1', '24.5', '23.5', '22.5', '21.4', '22.9', '21.6', '21.2',
#        '24', '21.7', '21.8', '22.8', '14', '15.7', '16.3', '15.5', '15.4',
#        '14.9', '14.8', '13.9', '14.1', '14.3', '19.3', '16.7', '17.4',
#        '16.1', '15', '15.9', '13.6', '14.5', '14.6', '14.7', '17.8',
#        '14.2', '18.1', '19.5', '20.3', '20.2', '20', '18.8', '17.5',
#        '16.2', '15.3', '25.5', '22.4', '21.1', '19.2', '18.9', '22.2',
#        '19.6', '18.5', '10.9', '19.8', '18.7', '10', '8.9', '15.1', '21',
#        '25', '27.6', '26.6', '27', '26.1', '25.6', '24.8', '23.8', '30',
#        '28.1', '29.8', '28.5', '28', '26.5', '26.2', '26.9', '24.2', '26',
#        '10.8', '25.8', '26.4', '23.9', '24.7', '20.5', '18', '13', '28.3',
#        '27.8', '28.9', '27.2', '29.1', '19', '24.6', '18.2', '24.4',
#        '25.3', '23.6', '20.8', '20.6', '16', '20.1', '19.9', '12', '14.4',
# ...

# %% [markdown]
# writing a function to clean and convert the column to float/int

# %%
def clean_columns(val):
  try:
    return float(val)
  except (ValueError, TypeError):
    return np.nan

# %%
df['water_temperature_c'] = df['water_temperature_c'].apply(clean_columns)

# %%
df['water_temperature_c'].unique()
# Out:
# array([  18.4 ,   22.6 ,   23.  ,   22.  ,   21.9 ,   22.1 ,   21.5 ,
#          21.3 ,   24.9 ,   25.1 ,   24.5 ,   23.5 ,   22.5 ,   21.4 ,
#          22.9 ,   21.6 ,   21.2 ,   24.  ,   21.7 ,   21.8 ,   22.8 ,
#          14.  ,   15.7 ,   16.3 ,   15.5 ,   15.4 ,   14.9 ,   14.8 ,
#          13.9 ,   14.1 ,   14.3 ,   19.3 ,   16.7 ,   17.4 ,   16.1 ,
#          15.  ,   15.9 ,   13.6 ,   14.5 ,   14.6 ,   14.7 ,   17.8 ,
#          14.2 ,   18.1 ,   19.5 ,   20.3 ,   20.2 ,   20.  ,   18.8 ,
#          17.5 ,   16.2 ,   15.3 ,   25.5 ,   22.4 ,   21.1 ,   19.2 ,
#          18.9 ,   22.2 ,   19.6 ,   18.5 ,   10.9 ,   19.8 ,   18.7 ,
#          10.  ,    8.9 ,   15.1 ,   21.  ,   25.  ,   27.6 ,   26.6 ,
#          27.  ,   26.1 ,   25.6 ,   24.8 ,   23.8 ,   30.  ,   28.1 ,
#          29.8 ,   28.5 ,   28.  ,   26.5 ,   26.2 ,   26.9 ,   24.2 ,
#          26.  ,   10.8 ,   25.8 ,   26.4 ,   23.9 ,   24.7 ,   20.5 ,
# ...

# %%
# confirming the col type
df['water_temperature_c'].dtype
# Out:
# dtype('float64')

# %%
df['water_temperature_c'].plot(kind='hist', bins=3)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['water_temperature_c'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['water_temperature_c'].skew()
# Out:
# np.float64(73.39624545764048)

# %%
df['water_temperature_c'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['water_temperature_c'] > 100]
# Out:
#      station depth_m       date  water_temperature_c oxygen_no_of_drops  \
# 3119     OP1       4 2006-08-27              1935.00                  0
#
#      do_meter_mg_per_l use_salinity_corrected_do secchi_depth_m total_depth_m  \
# 3119               NaN                       NaN            NaN          4.67
#
#      percent_secchi weather water_condition salinity_ppt  \
# 3119            NaN     NaN             NaN          1.9
#
#      conductivity_ms_per_cm po4_um nh4_um nox_um din_um don_um     tdn  \
# 3119                   3.44    0.2   46.8   0.65  47.45  98.77  146.22
#
#       poc_um pon_um c_n_ratio  ton_um   tn_um chla_ug_per_l phaeo_ug_per_l  \
# 3119  468.45  72.30      6.48  171.07  218.52         <0.05         136.57
#
#      ratio_chla_chla_phaeo total_pigments_ug_per_l sampling_depth_m
# 3119                  0.00                  136.60              4.0

# %% [markdown]
# seems like data entry error. converting 1935 to 19.35 (looking on the mean, this value  seems fine)

# %%
df.loc[3119, 'water_temperature_c'] = 19.35

# %%
df['water_temperature_c'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['water_temperature_c'].plot(kind='hist', bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['water_temperature_c'].plot(kind='box')
# Out:
# <Axes: >

# %%
# checking the outliers. - higher temp values
df[df['water_temperature_c'] > 60]
# Out:
#       station depth_m       date  water_temperature_c oxygen_no_of_drops  \
# 5324     GTP4       S 2015-07-19                67.00                 16
# 5325     GTP4       1 2015-07-19                79.00                 10
# 5326     GTP5       S 2015-07-19                68.00                 10
# 5327     GTP5       1 2015-07-19                68.00                 11
# 5328     GTP6       S 2015-07-19                67.00                 13
# 5329     GTP6       1 2015-07-19                67.00                 11
# 5330  LP Head       S 2015-07-19                65.00                 17
# 5331      LP1       S 2015-07-19                70.00                 17
# 5332      LP1       1 2015-07-19                75.00                 18
# 5333      LP2       S 2015-07-19                72.00                 12
# 5334      LP2       1 2015-07-19                74.00                 15
# 5335      LP3       S 2015-07-19                72.00                 11
# ...

# %%
# checking outliers. - lower temp values
df[df['water_temperature_c'] < 20]
# Out:
#      station depth_m       date  water_temperature_c oxygen_no_of_drops  \
# 0        GP1       S 1987-09-16                18.40                NaN
# 26       GP1       S 1987-10-19                14.00                NaN
# 27       GP2       S 1987-10-19                15.70                NaN
# 28       GP2       1 1987-10-19                16.30                NaN
# 29       GP3       S 1987-10-19                15.50                NaN
# ...      ...     ...        ...                  ...                ...
# 7473     OP3       6 2024-07-28                12.20                NaN
# 7520     OP1    3.25 2024-08-11                18.60                NaN
# 7527     OP3       6 2024-08-11                12.80                NaN
# 7558    GTP4       S 2024-08-25                19.50                NaN
# 7584     OP3       6 2024-08-29                13.60                NaN
#
#      do_meter_mg_per_l use_salinity_corrected_do secchi_depth_m total_depth_m  \
# ...

# %%
# in between temp
df[(df['water_temperature_c'] > 30) & (df['water_temperature_c'] < 40)]
# Out:
#       station depth_m       date  water_temperature_c oxygen_no_of_drops  \
# 480       VS1       S 1989-09-10                31.30                NaN
# 481       VS1       1 1989-09-10                30.50                NaN
# 482       VS1       2 1989-09-10                30.90                NaN
# 2943      GP2       1 2006-07-30                31.00                  6
# 2945     GP2A       1 2006-07-30                31.00                  7
# 4523      WF7       1 2011-08-21                35.00                 12
# 4882  OP Head       S 2013-07-16                30.10                NaN
# 6315     GTP4       1 2019-07-21                32.00                 18
# 6317     GTP5       1 2019-07-21                31.00                 18
# 6370     GTP4       1 2019-08-04                32.00                NaN
# 6372     GTP5       1 2019-08-04                31.00                NaN
#
#      do_meter_mg_per_l use_salinity_corrected_do secchi_depth_m total_depth_m  \
# ...

# %%
df['water_temperature_c'].isna().sum()
# Out:
# np.int64(1272)

# %%
df[(df['water_temperature_c'] > 0) & (df['water_temperature_c'] < 20)]
# Out:
#      station depth_m       date  water_temperature_c oxygen_no_of_drops  \
# 0        GP1       S 1987-09-16                18.40                NaN
# 26       GP1       S 1987-10-19                14.00                NaN
# 27       GP2       S 1987-10-19                15.70                NaN
# 28       GP2       1 1987-10-19                16.30                NaN
# 29       GP3       S 1987-10-19                15.50                NaN
# ...      ...     ...        ...                  ...                ...
# 7473     OP3       6 2024-07-28                12.20                NaN
# 7520     OP1    3.25 2024-08-11                18.60                NaN
# 7527     OP3       6 2024-08-11                12.80                NaN
# 7558    GTP4       S 2024-08-25                19.50                NaN
# 7584     OP3       6 2024-08-29                13.60                NaN
#
#      do_meter_mg_per_l use_salinity_corrected_do secchi_depth_m total_depth_m  \
# ...

# %% [markdown]
# # `oxygen_no_of_drops`
# ### Conclusions:
# - Value Ranges:
#
#     0-5 drops: Hypoxic/anoxic conditions (stress)
#
#     ***10-15 drops: Normal healthy levels (majority of the data)***
#
#     20+ drops: High oxygen (algal blooms, cold water)
#
#     30+ drops: Very high (rare but possible)
#
# - No further cleaning needed

# %%
df['oxygen_no_of_drops'].describe()
# Out:
# count     3056
# unique      78
# top         14
# freq       336
# Name: oxygen_no_of_drops, dtype: object

# %%
df['oxygen_no_of_drops'].isna().sum()
# Out:
# np.int64(4529)

# %%
df['oxygen_no_of_drops'].dtype
# Out:
# dtype('O')

# %%
df['oxygen_no_of_drops'].unique()
# Out:
# array([nan, '11', '16', '14', '13', '10', '15', '12', '18', '7', '9', '8',
#        '6', '17', '4', '3', '5', '20', '19', '21', '0', '25', '7.5', '23',
#        'NO COLOR', '6.59', '6.23', '5.93', '5.7', '6.43', '4.72', '6.68',
#        '5.96', '6.4', '5.84', '6.85', '6.03', '28', '2', '22', '1',
#        '16.00', '17.00', '14.00', '15.00', '11.00', '12.00', '13.00',
#        '12.60', '13.20', '13.30', '16.80', '11.40', '11.50', '13.94',
#        '14.12', '17.44', '15.08', '14.98', '14.08', '13.98', '13.58',
#        '15.4', '14.5', '14.14', '14.18', '14.02', '10.6', '11.6', '11.2',
#        '12.4', '11.8', '27', '26', '24', '3.5', '32', '10.5', '10.1'],
#       dtype=object)

# %%
df['oxygen_no_of_drops'] = df['oxygen_no_of_drops'].apply(clean_columns)

# %%
df['oxygen_no_of_drops'].unique()
# Out:
# array([  nan, 11.  , 16.  , 14.  , 13.  , 10.  , 15.  , 12.  , 18.  ,
#         7.  ,  9.  ,  8.  ,  6.  , 17.  ,  4.  ,  3.  ,  5.  , 20.  ,
#        19.  , 21.  ,  0.  , 25.  ,  7.5 , 23.  ,  6.59,  6.23,  5.93,
#         5.7 ,  6.43,  4.72,  6.68,  5.96,  6.4 ,  5.84,  6.85,  6.03,
#        28.  ,  2.  , 22.  ,  1.  , 12.6 , 13.2 , 13.3 , 16.8 , 11.4 ,
#        11.5 , 13.94, 14.12, 17.44, 15.08, 14.98, 14.08, 13.98, 13.58,
#        15.4 , 14.5 , 14.14, 14.18, 14.02, 10.6 , 11.6 , 11.2 , 12.4 ,
#        11.8 , 27.  , 26.  , 24.  ,  3.5 , 32.  , 10.5 , 10.1 ])

# %%
df['oxygen_no_of_drops'].describe()
# Out:
# count   3055.00
# mean      12.20
# std        4.03
# min        0.00
# 25%       10.00
# 50%       13.00
# 75%       15.00
# max       32.00
# Name: oxygen_no_of_drops, dtype: float64

# %%
df['oxygen_no_of_drops'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['oxygen_no_of_drops'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['oxygen_no_of_drops'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['oxygen_no_of_drops'] < 3]
# Out:
#       station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 2760      OP3     5.5 2005-07-10                13.50                0.00
# 2761      OP3       6 2005-07-24                 6.50                0.00
# 2763      OP3       6 2005-08-21                13.50                0.00
# 2881     GTP2       1 2006-07-16                24.00                0.00
# 2906      OP3       6 2006-07-16                16.00                0.00
# 2980      OP3       6 2006-07-30                15.00                0.00
# 3045      OP1       4 2006-08-13                18.00                0.00
# 3052      OP3       6 2006-08-13                15.00                0.00
# 3119      OP1       4 2006-08-27                19.35                0.00
# 3193      OP1       4 2007-07-08                16.50                0.00
# 3200      OP3       6 2007-07-08                13.00                0.00
# 3266      OP1       4 2007-07-22                17.00                0.00
# ...

# %%
# Check the current range
print("Oxygen drops - Current range:")
print(f"Min: {df['oxygen_no_of_drops'].min()}")
print(f"Max: {df['oxygen_no_of_drops'].max()}")
print(f"Mean: {df['oxygen_no_of_drops'].mean():.1f}")

# Check distribution
print("\nDistribution:")
print(df['oxygen_no_of_drops'].describe())

# Look for extreme values
print(f"\nValues > 50: {(df['oxygen_no_of_drops'] > 50).sum()}")
print(f"Values < 0: {(df['oxygen_no_of_drops'] < 0).sum()}")
# Out:
# Oxygen drops - Current range:
# Min: 0.0
# Max: 32.0
# Mean: 12.2
#
# Distribution:
# count   3055.00
# mean      12.20
# std        4.03
# min        0.00
# 25%       10.00
# 50%       13.00
# 75%       15.00
# max       32.00
# Name: oxygen_no_of_drops, dtype: float64
#
# Values > 50: 0
# Values < 0: 0

# %% [markdown]
# # `do_meter_mg_per_l`
# ### Conclusions:
# - values above 12.5 are measured for year 1989 to 1991 majorly. (about 50 rows)
# - There are little more outliers for values below 2
# - No further cleaning needed

# %%
df['do_meter_mg_per_l'].describe()
# Out:
# count     3535
# unique     831
# top        7.5
# freq       154
# Name: do_meter_mg_per_l, dtype: object

# %%
df['do_meter_mg_per_l'] = df['do_meter_mg_per_l'].apply(clean_columns)

# %%
df['do_meter_mg_per_l'].unique()
# Out:
# array([ 6.7 ,  4.5 ,  6.6 ,  6.5 ,  7.1 ,  7.8 ,  7.2 ,  8.3 ,  9.4 ,
#         9.3 ,  8.7 ,  8.8 ,  8.5 ,  9.2 ,  7.4 ,  6.1 ,  1.  ,  7.5 ,
#         8.  ,  0.7 ,  8.4 ,  0.8 ,  0.  ,  8.6 ,  9.6 ,  9.7 ,  9.5 ,
#         9.8 ,  7.7 ,  8.1 ,  8.2 ,  9.1 ,  0.5 , 13.8 , 17.4 , 18.3 ,
#        17.7 , 15.5 , 16.1 , 11.8 , 11.9 ,  7.9 ,  6.8 , 10.5 ,  7.  ,
#         0.4 ,  2.2 ,  1.6 ,  1.1 , 16.6 , 10.3 , 11.7 , 11.  , 10.9 ,
#        12.8 ,  0.6 ,  1.7 ,  9.  ,  6.  ,  3.  , 10.  ,  1.5 ,  5.5 ,
#         3.5 ,  5.  ,  4.  ,  2.5 ,  7.6 ,  5.6 ,  4.6 ,  8.9 , 11.4 ,
#        10.4 ,  9.9 , 11.5 , 12.3 , 10.6 , 11.6 , 12.  , 10.8 ,   nan,
#        11.2 , 10.7 , 10.55, 10.62, 11.53, 11.32, 11.29, 10.36, 11.3 ,
#         2.  ,  1.3 ,  4.2 ,  3.7 ,  4.7 ,  6.2 ,  5.7 ,  2.7 , 21.1 ,
#        25.6 , 25.  , 23.3 , 24.4 , 23.9 , 22.8 , 22.5 , 22.  , 25.5 ,
#        17.  , 23.  , 24.  , 14.  , 21.4 , 21.2 , 10.2 ,  5.2 , -0.8 ,
# ...

# %%
df['do_meter_mg_per_l'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7585 entries, 0 to 7584
# Series name: do_meter_mg_per_l
# Non-Null Count  Dtype
# --------------  -----
# 3509 non-null   float64
# dtypes: float64(1)
# memory usage: 59.4 KB

# %%
df['do_meter_mg_per_l'].describe()
# Out:
# count   3509.00
# mean       6.87
# std        4.00
# min       -0.80
# 25%        5.50
# 50%        7.00
# 75%        8.20
# max       92.80
# Name: do_meter_mg_per_l, dtype: float64

# %%
df['do_meter_mg_per_l'].plot(kind='hist', bins = 80)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['do_meter_mg_per_l'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['do_meter_mg_per_l'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['do_meter_mg_per_l'] > 30]
# Out:
#      station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 5961     BP1       S 2017-08-27                23.30                 NaN
# 5962     BP2       S 2017-08-27                23.50                 NaN
# 5963     BP2       B 2017-08-27                24.90                 NaN
# 5964     BP3       S 2017-08-27                25.10                 NaN
# 5965     BP3       B 2017-08-27                25.20                 NaN
#
#       do_meter_mg_per_l use_salinity_corrected_do secchi_depth_m  \
# 5961              92.80                       5.9            1.0
# 5962              78.50                       5.0            1.0
# 5963              80.40                       4.8            1.0
# 5964              61.90                       3.7            1.2
# 5965              62.50                       3.8            1.2
#
#      total_depth_m percent_secchi weather water_condition salinity_ppt  \
# ...

# %%
# Fix the obvious decimal point errors
df.loc[df['do_meter_mg_per_l'] > 30, 'do_meter_mg_per_l'] = df.loc[df['do_meter_mg_per_l'] > 30, 'do_meter_mg_per_l'] / 10

# %%
df[df['do_meter_mg_per_l'] > 30]
# Out:
# Empty DataFrame
# Columns: [station, depth_m, date, water_temperature_c, oxygen_no_of_drops, do_meter_mg_per_l, use_salinity_corrected_do, secchi_depth_m, total_depth_m, percent_secchi, weather, water_condition, salinity_ppt, conductivity_ms_per_cm, po4_um, nh4_um, nox_um, din_um, don_um, tdn, poc_um, pon_um, c_n_ratio, ton_um, tn_um, chla_ug_per_l, phaeo_ug_per_l, ratio_chla_chla_phaeo, total_pigments_ug_per_l, sampling_depth_m]
# Index: []

# %%
df['do_meter_mg_per_l'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['do_meter_mg_per_l'] < 2]
# Out:
#      station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 18       OP1       4 1987-09-16                21.20                 NaN
# 21       OP2     3.3 1987-09-16                24.00                 NaN
# 24       OP3       4 1987-09-16                22.80                 NaN
# 25       OP3       6 1987-09-16                22.80                 NaN
# 48       OP2     3.3 1987-10-19                18.40                 NaN
# ...      ...     ...        ...                  ...                 ...
# 7520     OP1    3.25 2024-08-11                18.60                 NaN
# 7527     OP3       6 2024-08-11                12.80                 NaN
# 7546    GP2A     0.5 2024-08-25                25.00                 NaN
# 7577     OP1       4 2024-08-29                20.00                 NaN
# 7584     OP3       6 2024-08-29                13.60                 NaN
#
#       do_meter_mg_per_l use_salinity_corrected_do secchi_depth_m  \
# ...

# %% [markdown]
# # `use_salinity_corrected_do`
# ### Conclusions:
# - This data is only available after year 2008.
# - outliers seems to be legit

# %%
df['use_salinity_corrected_do'].describe()
# Out:
# count     2730
# unique     862
# top        6.5
# freq        73
# Name: use_salinity_corrected_do, dtype: object

# %%
df['use_salinity_corrected_do'].isna().sum()
# Out:
# np.int64(4855)

# %%
df['use_salinity_corrected_do'] = df['use_salinity_corrected_do'].apply(clean_columns)

# %%
df['use_salinity_corrected_do'].describe()
# Out:
# count   2728.00
# mean       5.81
# std        2.22
# min        0.00
# 25%        4.54
# 50%        6.30
# 75%        7.28
# max       16.00
# Name: use_salinity_corrected_do, dtype: float64

# %%
df['use_salinity_corrected_do'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['use_salinity_corrected_do'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['use_salinity_corrected_do'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['use_salinity_corrected_do'] > 11]
# Out:
#      station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 4552    GTP2       S 2012-07-08                26.80                 NaN
# 5833     LP2       S 2017-07-16                24.30                 NaN
# 5835     LP3       S 2017-07-16                23.20                 NaN
# 6470     GP2       S 2020-07-12                27.00               25.00
# 6472    GP2A       S 2020-07-12                27.00               26.00
# 6474    GP3A       S 2020-07-12                28.00               32.00
# 6475    GP3A       1 2020-07-12                26.00               23.00
# 7235    GTP4       S 2023-07-23                28.00                 NaN
# 7371     BP2       S 2024-07-14                27.00               27.00
#
#       do_meter_mg_per_l  use_salinity_corrected_do secchi_depth_m  \
# 4552              12.95                      12.51            0.8
# 5833              14.14                      12.20            1.3
# ...

# %% [markdown]
# # `secchi_depth_m`
# ### Conclusions:
# - outliers needs more intervention. Need to do bivariate with secchi_depth_m and station
# - about 6 to 7 outliers. scroll down.
# confirm with micheline

# %%
df['secchi_depth_m'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7585 entries, 0 to 7584
# Series name: secchi_depth_m
# Non-Null Count  Dtype
# --------------  -----
# 4792 non-null   object
# dtypes: object(1)
# memory usage: 59.4+ KB

# %%
df['secchi_depth_m'].describe()
# Out:
# count     4792
# unique     210
# top        1.0
# freq       379
# Name: secchi_depth_m, dtype: object

# %%
df['secchi_depth_m'] = df['secchi_depth_m'].apply(clean_columns)

# %%
df['secchi_depth_m'].describe()
# Out:
# count   4792.00
# mean       1.27
# std        0.66
# min        0.00
# 25%        0.90
# 50%        1.20
# 75%        1.50
# max       11.50
# Name: secchi_depth_m, dtype: float64

# %%
df['secchi_depth_m'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['secchi_depth_m'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['secchi_depth_m'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['secchi_depth_m'] > 4]
# Out:
#      station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 2123     BP3       B 2003-07-13                  NaN                 NaN
# 2294     BP4       B 2004-08-22                22.50                 NaN
# 2302     BP5       B 2004-08-22                23.50                 NaN
# 2310     BP6       B 2004-08-22                21.70                 NaN
# 3054     VS1       S 2006-08-13                22.50               13.00
# 3055     VS1       1 2006-08-13                23.00               15.00
# 3056     VS1       2 2006-08-13                23.00               14.00
# 7528     VS1       S 2024-08-11                24.78               13.00
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# 2123               7.00                        NaN            5.00
# 2294               5.00                        NaN           11.50
# 2302               5.50                        NaN           10.00
# ...

# %% [markdown]
# # `total_depth_m`
# ### Conclusions:
# -
# - below are the outliers to be reviewed. Confirm with Micheline
# ![image.png](data:image/png;base64,...)

# %%
df['total_depth_m'] = df['total_depth_m'].apply(clean_columns)

# %%
df['total_depth_m'].describe()
# Out:
# count   4739.00
# mean       2.43
# std        2.79
# min        0.00
# 25%        1.30
# 50%        1.70
# 75%        2.70
# max       82.00
# Name: total_depth_m, dtype: float64

# %%
df['total_depth_m'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['total_depth_m'] > 20]
# Out:
#      station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 2391    GTP5       B 2004-07-25                21.00                 NaN
# 3340     OP3       2 2007-08-05                27.00               16.00
# 3341     OP3       4 2007-08-05                26.00               13.00
# 3342     OP3       6 2007-08-05                13.50                0.00
# 5578     WF8       2 2016-07-15                24.40                 NaN
# 5899     OP2       S 2017-07-30                22.50                 NaN
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# 2391               5.00                        NaN            1.30
# 3340                NaN                        NaN            2.30
# 3341                NaN                        NaN            2.30
# 3342                NaN                        NaN            2.30
# 5578               6.16                       5.26            2.10
# ...

# %% [markdown]
# # `salinity_ppt`
# ### Conclusions:
#
# - Overall salinity_ppt column looks fine.
#
# - Salinity 0–2 ppt: Very low, close to freshwater, typical of estuary upper regions; supports freshwater and low-salinity species.
#
# - Salinity 20–30 ppt: Moderate to high, near marine conditions, found in lower estuary areas; supports salt-tolerant marine and estuarine life.

# %%
df['salinity_ppt'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7585 entries, 0 to 7584
# Series name: salinity_ppt
# Non-Null Count  Dtype
# --------------  -----
# 7302 non-null   object
# dtypes: object(1)
# memory usage: 59.4+ KB

# %%
df['salinity_ppt'] = df['salinity_ppt'].apply(clean_columns)

# %%
df['salinity_ppt'].describe()
# Out:
# count   7301.00
# mean      22.52
# std       10.72
# min        0.00
# 25%       18.70
# 50%       27.30
# 75%       29.60
# max      311.00
# Name: salinity_ppt, dtype: float64

# %%
df['salinity_ppt'].plot(kind='box')
# Out:
# <Axes: >

# %%
# this is an obvious typing mistake.. changing it to 30 instead of 300
df[df['salinity_ppt'] > 70]
# Out:
#      station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 5518     BP6       1 2016-07-10                21.10               14.00
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# 5518                NaN                        NaN            1.31
#
#       total_depth_m percent_secchi weather water_condition  salinity_ppt  \
# 5518           1.31           1.00     NaN             NaN        311.00
#
#      conductivity_ms_per_cm po4_um nh4_um nox_um din_um don_um    tdn poc_um  \
# 5518                  48.20   0.53   1.27   0.12   1.39  34.14  35.54  45.65
#
#      pon_um c_n_ratio ton_um  tn_um chla_ug_per_l phaeo_ug_per_l  \
# 5518   6.01      7.60  40.15  41.55          2.35           2.43
#
#      ratio_chla_chla_phaeo total_pigments_ug_per_l sampling_depth_m
# 5518                  0.49                    4.78              1.0

# %%
df.at[5518, 'salinity_ppt'] = 30

# %%
df[df['salinity_ppt'] > 70]
# Out:
# Empty DataFrame
# Columns: [station, depth_m, date, water_temperature_c, oxygen_no_of_drops, do_meter_mg_per_l, use_salinity_corrected_do, secchi_depth_m, total_depth_m, percent_secchi, weather, water_condition, salinity_ppt, conductivity_ms_per_cm, po4_um, nh4_um, nox_um, din_um, don_um, tdn, poc_um, pon_um, c_n_ratio, ton_um, tn_um, chla_ug_per_l, phaeo_ug_per_l, ratio_chla_chla_phaeo, total_pigments_ug_per_l, sampling_depth_m]
# Index: []

# %%
df['salinity_ppt'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['salinity_ppt'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['salinity_ppt'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # `conductivity_ms_per_cm`
# ### Conclusions:
#
# - This col seems perfectly fine.
# - I did notice that this conductivity col is highly corelated with salinity col

# %%
df['conductivity_ms_per_cm'].describe()
# Out:
# count     4721
# unique    1103
# top        0.2
# freq        50
# Name: conductivity_ms_per_cm, dtype: object

# %%
df['conductivity_ms_per_cm'] = df['conductivity_ms_per_cm'].apply(clean_columns)

# %%
df['conductivity_ms_per_cm'].describe()
# Out:
# count   4707.00
# mean      33.09
# std       17.71
# min        0.00
# 25%       16.49
# 50%       42.80
# 75%       46.10
# max       50.40
# Name: conductivity_ms_per_cm, dtype: float64

# %%
df['conductivity_ms_per_cm'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['conductivity_ms_per_cm'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['conductivity_ms_per_cm'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # `po4_um`
# ### Conclusions:
#
# - major outliers are dropped
# - still there are about 250 datapoints that can be categorized as outliers. But this is legit data.

# %%
df[df['po4_um'] == '<0.1']
# Out:
#      station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 1278     BP2       S 1997-07-28                  NaN                 NaN
# 1307    GTP5       S 1997-07-28                  NaN                 NaN
# 1308    GTP5       1 1997-07-28                  NaN                 NaN
# 1309    GTP6       S 1997-07-28                  NaN                 NaN
# 1315     BP2       S 1997-08-10                  NaN                 NaN
# ...      ...     ...        ...                  ...                 ...
# 5165     GP5    0.15 2014-07-20                23.00               17.00
# 5174    GTP3       1 2014-07-20                24.30                 NaN
# 5274     OP1       2 2014-08-20                24.10                 NaN
# 5278     OP2    3.25 2014-08-20                23.80                 NaN
# 5279     OP3    0.15 2014-08-20                24.50                 NaN
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# ...

# %% [markdown]
# Replacing values with '<0.1' to 0.05 as half of detection limit

# %%
df['po4_um'] = df['po4_um'].replace('<0.1', 0.05)

# %%
df['po4_um'].unique()
# Out:
# array(['0.2', '0.1', '0.4', '0.6', '0.5', '0.7', '0.04', '0.03', '1.2',
#        '6.5', '0.3', '25', '53', '0.29', '0.09', '0.01', '0.14', '0.89',
#        '0.24', '2.89', '0.19', '0.54', '18.74', '24.92', '1.07', '0.02',
#        '0.51', '0.38', '0.07', '0.18', '0.74', '0.43', '0.48', '0.36',
#        '0.59', '0.41', '0.05', '3.82', '0.23', '0.79', '1.15', '0.12',
#        '3.21', '8.5', '0.64', '0.25', '0.58', '4.93', '0.15', '1.69',
#        '5.26', '13.38', '0.46', '2.14', '0.33', '2.3', '1.31', '1.54',
#        '1.39', '1.34', '1.09', '0.93', '0.08', '0.68', '0.53', '0.13',
#        '7.51', '0.88', '4.87', '9.35', '9.56', '19.77', '0.61', '0',
#        '0.86', '0.81', '0.76', '0.28', '0.56', '3', '10.07', '11.05',
#        '0.62', '0.32', '0.47', '0.42', '0.45', '0.37', '0.67', '0.72',
#        '0.82', '11.46', '18.45', '0.75', '0.8', '0.77', '0.85', '0.49',
#        '0.31', '0.26', '1.52', '11.11', '16.84', '0.52', '0.35', '1.13',
# ...

# %%
df['po4_um'] = df['po4_um'].apply(clean_columns)

# %%
df['po4_um'].dtype
# Out:
# dtype('float64')

# %%
df['po4_um'].describe()
# Out:
# count   7571.00
# mean       0.92
# std        5.25
# min        0.00
# 25%        0.10
# 50%        0.30
# 75%        0.58
# max      221.50
# Name: po4_um, dtype: float64

# %%
df['po4_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['po4_um'] > 20]
# Out:
#       station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 51        OP3       4 1987-10-19                17.80                 NaN
# 52        OP3       6 1987-10-19                17.80                 NaN
# 84        OP3       6 1988-05-27                 8.90                 NaN
# 314       OP3       6 1989-03-10                 4.00                 NaN
# 347       OP3       6 1989-05-21                10.00                 NaN
# 512       OP3     5.3 1989-10-15                14.00                 NaN
# 545       OP3       6 1990-07-15                12.60                 NaN
# 600       OP3       6 1990-07-29                13.10                 NaN
# 766       OP3       6 1991-07-14                11.00                 NaN
# 819       OP3       6 1991-07-28                11.00                 NaN
# 978       OP3       6 1994-07-17                12.80                 NaN
# 1047      OP3       6 1994-07-31                13.60                 NaN
# ...

# %% [markdown]
# # value of po4_um cannot be more than 20um in any case. It's generally impossible.
# - Clean estuarine: 0.1-1.0 μM
# - Moderately polluted: 1.0-5.0 μM
# - Heavily polluted: 5.0-15.0 μM
# - Extremely polluted: 15.0-20.0 μM
# - Impossible: >20.0 μM
#
# I am dropping all the above index rows. since all the other values are also inflated due to this.

# %%
po4_drop_index = df[df['po4_um'] > 20].index

# %%
df.drop(po4_drop_index, inplace=True)

# %%
df[df['po4_um'] > 20]
# Out:
# Empty DataFrame
# Columns: [station, depth_m, date, water_temperature_c, oxygen_no_of_drops, do_meter_mg_per_l, use_salinity_corrected_do, secchi_depth_m, total_depth_m, percent_secchi, weather, water_condition, salinity_ppt, conductivity_ms_per_cm, po4_um, nh4_um, nox_um, din_um, don_um, tdn, poc_um, pon_um, c_n_ratio, ton_um, tn_um, chla_ug_per_l, phaeo_ug_per_l, ratio_chla_chla_phaeo, total_pigments_ug_per_l, sampling_depth_m]
# Index: []

# %%
df['po4_um'].describe()
# Out:
# count   7518.00
# mean       0.57
# std        1.39
# min        0.00
# 25%        0.10
# 50%        0.30
# 75%        0.56
# max       19.77
# Name: po4_um, dtype: float64

# %%
df['po4_um'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['po4_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['po4_um'] > 2.5]
# Out:
#      station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 25       OP3       6 1987-09-16                22.80                 NaN
# 80       OP2     3.3 1988-05-27                10.90                 NaN
# 83       OP3       4 1988-05-27                10.00                 NaN
# 109      OP1       4 1988-07-06                19.60                 NaN
# 115      OP3       4 1988-07-06                14.30                 NaN
# ...      ...     ...        ...                  ...                 ...
# 7210     OP3       6 2023-07-09                13.80                 NaN
# 7312     OP3       6 2023-08-06                12.40                 NaN
# 7365     OP3       4 2023-08-20                23.40                 NaN
# 7419     OP3       4 2024-07-14                25.70                 NaN
# 7466     OP1       4 2024-07-28                17.80                 NaN
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# ...

# %% [markdown]
# # `nh4_um`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline

# %%
df['nh4_um']
# Out:
# 0        1.7
# 1          5
# 2        4.8
# 3        3.3
# 4        5.5
#         ...
# 7579    1.16
# 7580    1.07
# 7581    3.00
# 7582    3.82
# 7583    1.44
# Name: nh4_um, Length: 7532, dtype: object

# %%
df['nh4_um'] = df['nh4_um'].replace('<0.1','0.05')

# %%
df['nh4_um'] = df['nh4_um'].replace('<0.05','0.05')

# %%
#confirm
df[df['nh4_um'] == '0.05']
# Out:
#       station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 350       VS1       2 1989-05-21                14.30                 NaN
# 1438     GP2A       1 1998-08-02                  NaN                 NaN
# 1458      VS1       1 1998-08-02                  NaN                 NaN
# 1580     GP2A       S 1999-07-25                  NaN                 NaN
# 1581     GP2A     1.0 1999-07-25                  NaN                 NaN
# ...       ...     ...        ...                  ...                 ...
# 6346      BP5       B 2019-08-04                27.50                7.00
# 6382  OP Head       S 2019-08-04                29.30                 NaN
# 6984      LP1       S 2022-07-17                25.50               13.00
# 7317      BP2       S 2023-08-20                23.00               12.00
# 7346     GTP5       B 2023-08-20                22.50                 NaN
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# ...

# %%
df['nh4_um'].isna().sum()
# Out:
# np.int64(16)

# %%
df['nh4_um'] = df['nh4_um'].apply(clean_columns)

# %%
df['nh4_um'].isna().sum()
# Out:
# np.int64(18)

# %%
df['nh4_um'].dtype
# Out:
# dtype('float64')

# %%
df['nh4_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['nh4_um'] > 200]
# Out:
#      station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 24       OP3       4 1987-09-16                22.80                 NaN
# 25       OP3       6 1987-09-16                22.80                 NaN
# 83       OP3       4 1988-05-27                10.00                 NaN
# 116      OP3       6 1988-07-06                10.80                 NaN
# 149      OP3       6 1988-07-17                13.00                 NaN
# 182      OP3     5.3 1988-08-14                14.00                 NaN
# 215      OP3     5.3 1988-09-11                15.50                 NaN
# 247      OP3       4 1988-10-16                12.80                 NaN
# 248      OP3     5.3 1988-10-16                12.50                 NaN
# 280      OP3       4 1989-01-19                 3.00                 NaN
# 281      OP3       6 1989-01-19                 4.40                 NaN
# 313      OP3       4 1989-03-10                 2.50                 NaN
# ...

# %%
# removing outliers
df.loc[df['nh4_um'] > 200, 'nh4_um'] = np.nan
df.loc[df['nh4_um'] < 0, 'nh4_um'] = np.nan

# %%
df[df['nh4_um'] > 200]
# Out:
# Empty DataFrame
# Columns: [station, depth_m, date, water_temperature_c, oxygen_no_of_drops, do_meter_mg_per_l, use_salinity_corrected_do, secchi_depth_m, total_depth_m, percent_secchi, weather, water_condition, salinity_ppt, conductivity_ms_per_cm, po4_um, nh4_um, nox_um, din_um, don_um, tdn, poc_um, pon_um, c_n_ratio, ton_um, tn_um, chla_ug_per_l, phaeo_ug_per_l, ratio_chla_chla_phaeo, total_pigments_ug_per_l, sampling_depth_m]
# Index: []

# %%
df['nh4_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
# need to confirm this
df[df['nh4_um'] > 20 ]
# Out:
#       station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 9     LP Head       S 1987-09-16                24.90                 NaN
# 18        OP1       4 1987-09-16                21.20                 NaN
# 36    LP Head       S 1987-10-19                19.30                 NaN
# 48        OP2     3.3 1987-10-19                18.40                 NaN
# 68    LP Head       S 1988-05-27                25.50                 NaN
# ...       ...     ...        ...                  ...                 ...
# 7359      OP1       4 2023-08-20                22.20                 NaN
# 7365      OP3       4 2023-08-20                23.40                 NaN
# 7466      OP1       4 2024-07-28                17.80                 NaN
# 7472      OP3       4 2024-07-28                24.60                 NaN
# 7577      OP1       4 2024-08-29                20.00                 NaN
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# ...

# %% [markdown]
# # `nox_um`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline

# %%
df['nox_um'].describe()
# Out:
# count     7514
# unique    1718
# top       0.03
# freq       336
# Name: nox_um, dtype: object

# %%
df['nox_um'].unique()
# Out:
# array(['26.1', '43.2', '2.1', ..., '67.36', '13.95', '4.43'], dtype=object)

# %%
df['nox_um'] = df['nox_um'].replace('<0.1','0.05')

# %%
df['nox_um'] = df['nox_um'].replace('<0.05','0.05')

# %%
df['nox_um'].isna().sum()
# Out:
# np.int64(18)

# %%
df['nox_um'] = df['nox_um'].apply(clean_columns)

# %%
df['nox_um'].isna().sum()
# Out:
# np.int64(22)

# %%
df['nox_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.loc[df['nox_um'] > 100, 'nox_um'] = np.nan
df.loc[df['nox_um'] < 0, 'nox_um'] = np.nan

# %%
df['nox_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['nox_um'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # `din_um`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline

# %%
df['din_um'].describe()
# Out:
# count     7507
# unique    2361
# top        0.7
# freq        54
# Name: din_um, dtype: object

# %%
df['din_um'] = df['din_um'].replace('<0.1','0.05')
df['din_um'] = df['din_um'].replace('<0.05','0.05')

# %%
df['din_um'].isna().sum()
# Out:
# np.int64(25)

# %%
df['din_um'] = df['din_um'].apply(clean_columns)

# %%
df['din_um'].isna().sum()
# Out:
# np.int64(30)

# %%
df['din_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
drop_index = df[df['din_um'] > 300].index

# %%
df.drop(drop_index, inplace=True)

# %%
df['din_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['din_um'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # `don_um`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline

# %%
df['don_um'] = df['don_um'].replace('<0.1','0.05')
df['don_um'] = df['don_um'].replace('<0.05','0.05')
df['don_um'].isna().sum()
df['don_um'] = df['don_um'].apply(clean_columns)
df['don_um'].isna().sum()
df['don_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
drop_index =  df[df['don_um'] > 300].index
df.drop(drop_index, inplace=True)

# %%
df['don_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['don_um'] < 0]
# Out:
#       station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 132   LP Head       S 1988-07-17                23.90                 NaN
# 288      GP2A       S 1989-03-10                 2.50                 NaN
# 334       LP2       1 1989-05-21                20.00                 NaN
# 1534      BP1       S 1999-07-11                  NaN                 NaN
# 1758      BP6     1.0 2000-08-06                  NaN                 NaN
# 2104      GP5       2 2002-08-25                  NaN                 NaN
# 2108     GTP3       S 2002-08-25                  NaN                 NaN
# 5399      OP3       6 2015-08-12                18.70                 NaN
# 5522     GP2A       S 2016-07-10                21.50                9.00
# 5917      GP1       S 2017-08-13                22.00                9.00
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# 132                7.00                        NaN             NaN
# ...

# %%
df.loc[df['don_um'] < 0, 'don_um'] = np.nan

# %%
df[df['don_um'] < 0]
# Out:
# Empty DataFrame
# Columns: [station, depth_m, date, water_temperature_c, oxygen_no_of_drops, do_meter_mg_per_l, use_salinity_corrected_do, secchi_depth_m, total_depth_m, percent_secchi, weather, water_condition, salinity_ppt, conductivity_ms_per_cm, po4_um, nh4_um, nox_um, din_um, don_um, tdn, poc_um, pon_um, c_n_ratio, ton_um, tn_um, chla_ug_per_l, phaeo_ug_per_l, ratio_chla_chla_phaeo, total_pigments_ug_per_l, sampling_depth_m]
# Index: []

# %%
df['don_um'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # `tdn`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline

# %%
df['tdn'] = df['tdn'].replace('<0.1','0.05')
df['tdn'] = df['tdn'].replace('<0.05','0.05')
df['tdn'].isna().sum()
df['tdn'] = df['tdn'].apply(clean_columns)
df['tdn'].isna().sum()
df['tdn'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['tdn'] > 400]
# Out:
#      station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 6942     OP3       6 2021-08-29                  NaN                 NaN
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# 6942                NaN                        NaN            2.10
#
#       total_depth_m percent_secchi weather water_condition  salinity_ppt  \
# 6942           4.90             43     NaN             NaN         15.30
#
#       conductivity_ms_per_cm  po4_um  nh4_um  nox_um  din_um  don_um    tdn  \
# 6942                   25.18    5.47     NaN    0.73  292.11  241.88 533.99
#
#        poc_um  pon_um c_n_ratio  ton_um   tn_um chla_ug_per_l phaeo_ug_per_l  \
# 6942  4072.23  407.30     10.00  649.18  941.29          0.03          74.71
#
#      ratio_chla_chla_phaeo total_pigments_ug_per_l sampling_depth_m
# 6942                  0.00                   74.74              NaN

# %%
df.drop(6942, inplace=True)

# %%
df['tdn'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['tdn'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # `poc_um`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline

# %%
df['poc_um'] = df['poc_um'].replace('<0.1','0.05')
df['poc_um'] = df['poc_um'].replace('<0.05','0.05')
df['poc_um'].isna().sum()
df['poc_um'] = df['poc_um'].apply(clean_columns)
df['poc_um'].isna().sum()
df['poc_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['poc_um'] > 2000 ]
# Out:
#       station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 870       OP3       2 1991-08-11                23.20                 NaN
# 2430  OP Head     NaN 2004-07-11                17.00                 NaN
# 2431  OP Head     NaN 2004-07-25                16.00                 NaN
# 2432  OP Head     NaN 2004-08-08                16.00                 NaN
# 2766  OP Head       S 2005-08-07                18.00                 NaN
# 2767  OP Head     NaN 2005-08-21                20.00                9.00
# 2970  LP Head       S 2006-07-30                23.00               21.00
# 3201  OP Head       S 2007-07-08                17.00               11.00
# 4042  OP Head       S 2010-07-18                20.00               12.00
# 4685      GP1       S 2012-08-05                21.30                 NaN
# 5666      GP1       S 2016-08-07                23.50                7.00
# 6518      WF8       7 2020-07-16                25.70                 NaN
#
# ...

# %%
df.loc[df['poc_um'] > 2000, 'poc_um'] = np.nan

# %%
df[df['poc_um'] > 2000 ]
# Out:
# Empty DataFrame
# Columns: [station, depth_m, date, water_temperature_c, oxygen_no_of_drops, do_meter_mg_per_l, use_salinity_corrected_do, secchi_depth_m, total_depth_m, percent_secchi, weather, water_condition, salinity_ppt, conductivity_ms_per_cm, po4_um, nh4_um, nox_um, din_um, don_um, tdn, poc_um, pon_um, c_n_ratio, ton_um, tn_um, chla_ug_per_l, phaeo_ug_per_l, ratio_chla_chla_phaeo, total_pigments_ug_per_l, sampling_depth_m]
# Index: []

# %%
df['poc_um'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['poc_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['poc_um'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # `pon_um`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline

# %%
df['pon_um'] = df['pon_um'].replace('<0.1','0.05')
df['pon_um'] = df['pon_um'].replace('<0.05','0.05')
df['pon_um'].isna().sum()
df['pon_um'] = df['pon_um'].apply(clean_columns)
df['pon_um'].isna().sum()
df['pon_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['pon_um'] > 200 ]
# Out:
#       station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 805       LP2       S 1991-07-28                25.00                 NaN
# 870       OP3       2 1991-08-11                23.20                 NaN
# 915   OP Head       S 1991-09-08                17.00                 NaN
# 2008      BP2       S 2002-07-28                  NaN                 NaN
# 2314      GP1       S 2004-08-22                20.00                 NaN
# 2431  OP Head     NaN 2004-07-25                16.00                 NaN
# 2432  OP Head     NaN 2004-08-08                16.00                 NaN
# 2766  OP Head       S 2005-08-07                18.00                 NaN
# 2767  OP Head     NaN 2005-08-21                20.00                9.00
# 2970  LP Head       S 2006-07-30                23.00               21.00
# 3201  OP Head       S 2007-07-08                17.00               11.00
# 3561      WF1       1 2008-07-27                21.50                 NaN
# ...

# %%
df.loc[df['pon_um'] > 200, 'pon_um'] = np.nan

# %%
df[df['pon_um'] > 200 ]
# Out:
# Empty DataFrame
# Columns: [station, depth_m, date, water_temperature_c, oxygen_no_of_drops, do_meter_mg_per_l, use_salinity_corrected_do, secchi_depth_m, total_depth_m, percent_secchi, weather, water_condition, salinity_ppt, conductivity_ms_per_cm, po4_um, nh4_um, nox_um, din_um, don_um, tdn, poc_um, pon_um, c_n_ratio, ton_um, tn_um, chla_ug_per_l, phaeo_ug_per_l, ratio_chla_chla_phaeo, total_pigments_ug_per_l, sampling_depth_m]
# Index: []

# %%
df['pon_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['pon_um'] > 60 ]
# Out:
#       station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 58       GP2A       S 1988-05-27                20.20                 NaN
# 59       GP2A       1 1988-05-27                20.00                 NaN
# 79        OP2       2 1988-05-27                18.50                 NaN
# 80        OP2     3.3 1988-05-27                10.90                 NaN
# 82        OP3       2 1988-05-27                18.70                 NaN
# ...       ...     ...        ...                  ...                 ...
# 7275      GP2       B 2023-08-06                24.40                 NaN
# 7285     GTP2       S 2023-08-06                26.00                8.00
# 7340     GTP2       B 2023-08-20                27.00                 NaN
# 7349  LP Head       S 2023-08-20                22.00                6.00
# 7520      OP1    3.25 2024-08-11                18.60                 NaN
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# ...

# %% [markdown]
# # `c_n_ratio`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline
# - df[df['c_n_ratio']  > 20] about 300 rows for this ..

# %%
df['c_n_ratio'].describe()
# Out:
# count     7335
# unique    1157
# top       6.31
# freq        43
# Name: c_n_ratio, dtype: object

# %%
df['c_n_ratio'].unique()
# Out:
# array(['9.51', '6.87', '5.17', ..., '4.78', '11.03', 'machine error'],
#       dtype=object)

# %%
df['c_n_ratio'] = df['c_n_ratio'].replace('<0.1','0.05')
df['c_n_ratio'] = df['c_n_ratio'].replace('<0.05','0.05')
df['c_n_ratio'].isna().sum()
df['c_n_ratio'] = df['c_n_ratio'].apply(clean_columns)
df['c_n_ratio'].isna().sum()
df['c_n_ratio'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['c_n_ratio']  > 20]
# Out:
#       station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 430       LP1       S 1989-08-13                23.00                 NaN
# 516       GP1       0 1990-07-15                17.50                 NaN
# 701   OP Head       0 1990-09-09                14.20                 NaN
# 1038      OP1       S 1994-07-31                27.50                 NaN
# 1039      OP1       2 1994-07-31                27.50                 NaN
# ...       ...     ...        ...                  ...                 ...
# 7432      BP5       B 2024-07-28                25.70                 NaN
# 7433      BP6       S 2024-07-28                29.70                 NaN
# 7434      BP6       B 2024-07-28                24.70                 NaN
# 7435      GP1       S 2024-07-28                21.40                 NaN
# 7436      GP2       S 2024-07-28                24.90                 NaN
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# ...

# %% [markdown]
# # `ton_um`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline

# %%
df['ton_um'] = df['ton_um'].replace('<0.1','0.05')
df['ton_um'] = df['ton_um'].replace('<0.05','0.05')
df['ton_um'].isna().sum()
df['ton_um'] = df['ton_um'].apply(clean_columns)
df['ton_um'].isna().sum()
df['ton_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['ton_um'] > 350]
# Out:
#       station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 28        GP2       1 1987-10-19                16.30                 NaN
# 29        GP3       S 1987-10-19                15.50                 NaN
# 30        GP3       1 1987-10-19                15.40                 NaN
# 45        OP1       4 1987-10-19                13.60                 NaN
# 46        OP2       S 1987-10-19                14.50                 NaN
# 48        OP2     3.3 1987-10-19                18.40                 NaN
# 49        OP3       S 1987-10-19                14.80                 NaN
# 50        OP3       2 1987-10-19                14.70                 NaN
# 915   OP Head       S 1991-09-08                17.00                 NaN
# 2432  OP Head     NaN 2004-08-08                16.00                 NaN
# 2766  OP Head       S 2005-08-07                18.00                 NaN
# 2767  OP Head     NaN 2005-08-21                20.00                9.00
# ...

# %%
df.loc[df['ton_um'] > 200, 'ton_um'] = np.nan
df.loc[df['ton_um'] < 0, 'ton_um'] = np.nan

# %%
df['ton_um'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # `tn_um`
# ### Conclusions:
#
# - This col looks fine

# %%
df['tn_um'] = df['tn_um'].replace('<0.1','0.05')
df['tn_um'] = df['tn_um'].replace('<0.05','0.05')
df['tn_um'].isna().sum()
df['tn_um'] = df['tn_um'].apply(clean_columns)
df['tn_um'].isna().sum()
# Out:
# np.int64(151)

# %%
df['tn_um'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['tn_um'] > 500 ]
# Out:
#       station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 2431  OP Head     NaN 2004-07-25                16.00                 NaN
# 2432  OP Head     NaN 2004-08-08                16.00                 NaN
# 2766  OP Head       S 2005-08-07                18.00                 NaN
# 2767  OP Head     NaN 2005-08-21                20.00                9.00
# 4042  OP Head       S 2010-07-18                20.00               12.00
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# 2431               5.50                        NaN             NaN
# 2432               5.50                        NaN             NaN
# 2766                NaN                        NaN             NaN
# 2767                NaN                        NaN             NaN
# 4042                NaN                        NaN             NaN
#
#       total_depth_m percent_secchi weather water_condition  salinity_ppt  \
# ...

# %%
df.loc[df['tn_um'] > 500, 'tn_um'] = np.nan

# %%
df['tn_um'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # `chla_ug_per_l`
# ### Conclusions:
#
# - This looks fine

# %%
df['chla_ug_per_l'].describe()
# Out:
# count      5816
# unique     2435
# top       <0.05
# freq         61
# Name: chla_ug_per_l, dtype: object

# %%
df['chla_ug_per_l'].isna().sum()
# Out:
# np.int64(1669)

# %%
df['chla_ug_per_l'] = df['chla_ug_per_l'].replace('<0.1','0.05')
df['chla_ug_per_l'] = df['chla_ug_per_l'].replace('<0.05','0.05')
df['chla_ug_per_l'] = df['chla_ug_per_l'].apply(clean_columns)
df['chla_ug_per_l'].isna().sum()
# Out:
# np.int64(1679)

# %%
df['chla_ug_per_l'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['chla_ug_per_l'] > 200]
# Out:
#      station depth_m       date  water_temperature_c  oxygen_no_of_drops  \
# 1779    GTP5     1.0 2000-08-06                  NaN                 NaN
# 2314     GP1       S 2004-08-22                20.00                 NaN
# 3902     OP1       4 2009-08-09                19.00                2.00
# 4114     LP3       1 2010-08-01                22.00               15.00
# 6330     OP1       B 2019-07-21                22.50                 NaN
#
#       do_meter_mg_per_l  use_salinity_corrected_do  secchi_depth_m  \
# 1779                NaN                        NaN             NaN
# 2314               5.00                        NaN            0.50
# 3902                NaN                        NaN            2.40
# 4114                NaN                        NaN             NaN
# 6330               3.81                       3.78            1.60
#
#       total_depth_m percent_secchi weather water_condition  salinity_ppt  \
# ...

# %%
df.loc[df['chla_ug_per_l'] > 200, 'chla_ug_per_l'] = np.nan

# %%
df['chla_ug_per_l'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # `phaeo_ug_per_l`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline

# %%
df['phaeo_ug_per_l'] = df['phaeo_ug_per_l'].replace('<0.1','0.05')
df['phaeo_ug_per_l'] = df['phaeo_ug_per_l'].replace('<0.05','0.05')
df['phaeo_ug_per_l'] = df['phaeo_ug_per_l'].apply(clean_columns)

# %%
df['phaeo_ug_per_l'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.loc[df['phaeo_ug_per_l'] > 150, 'phaeo_ug_per_l'] = np.nan

# %%
df['phaeo_ug_per_l'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # `ratio_chla_chla_phaeo`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline

# %%
df['ratio_chla_chla_phaeo'].isna().sum()
# Out:
# np.int64(1675)

# %%
df['ratio_chla_chla_phaeo'] = df['ratio_chla_chla_phaeo'].replace('<0.1','0.05')
df['ratio_chla_chla_phaeo'] = df['ratio_chla_chla_phaeo'].replace('<0.05','0.05')
df['ratio_chla_chla_phaeo'] = df['ratio_chla_chla_phaeo'].apply(clean_columns)

# %%
df['ratio_chla_chla_phaeo'].isna().sum()
# Out:
# np.int64(1686)

# %%
df['ratio_chla_chla_phaeo'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # `total_pigments_ug_per_l`
# ### Conclusions:
#
# - even after removing outliers, there are still few issues with outliers. confirm with micheline

# %%
df['total_pigments_ug_per_l'].isna().sum()
# Out:
# np.int64(1667)

# %%
df['total_pigments_ug_per_l'] = df['total_pigments_ug_per_l'].replace('<0.1','0.05')
df['total_pigments_ug_per_l'] = df['total_pigments_ug_per_l'].replace('<0.05','0.05')
df['total_pigments_ug_per_l'] = df['total_pigments_ug_per_l'].apply(clean_columns)

# %%
df['total_pigments_ug_per_l'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.loc[df['total_pigments_ug_per_l'] > 300, 'total_pigments_ug_per_l'] = np.nan

# %%
df['total_pigments_ug_per_l'].plot(kind='box')
# Out:
# <Axes: >
